# %%
# %sql
select * from workspace.damg7370.demo_cust_bronze_sd --cust1
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
select * from workspace.damg7370.demo_cust_bronze_sd --cust2
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
select * from workspace.damg7370.demo_cust_bronze_sd --cust3
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
select * from workspace.damg7370.demo_cust_silver_sd --cust3
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
select * from workspace.damg7370.demo_cust_bronze_sd where CustomerID='C011' --cust3 Last Row
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Age</th><th>City</th><th>CustomerID</th><th>Email</th><th>FullName</th><th>Gender</th><th>LoyaltyStatus</th><th>PhoneNumber</th><th>SignupDate</th><th>_rescued_data</th><th>ingestion_datetime</th><th>source_filename</th></tr></thead><tbody><tr><td>55</td><td>Woodsport</td><td>C011</td><td>matthewthomas@example.net</td><td>Benjamin Fernandez</td><td>Male</td><td>Bronze</td><td>520-274-1325</td><td>2024-09-18</td><td>null</td><td>2025-11-15T22:27:07.392Z</td><td>/Volumes/workspace/damg7370/datastore/schema_drift/customer_data_3.json</td></tr></tbody></table></div>

# %%
# %sql
select * from workspace.damg7370.demo_cust_silver_sd
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
select CreditScore from workspace.damg7370.demo_cust_silver_sd --cust4
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...
